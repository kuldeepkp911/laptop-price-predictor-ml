# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\laptop_data.csv')

# %%
df.sample(5)
# Out:
#      Unnamed: 0    Company   TypeName  Inches       ScreenResolution  \
# 2             2         HP   Notebook    15.6      Full HD 1920x1080
# 719         719         HP   Notebook    17.3      Full HD 1920x1080
# 360         360         HP   Notebook    15.6               1366x768
# 500         500       Asus    Netbook    11.6               1366x768
# 670         670  Microsoft  Ultrabook    13.5  Touchscreen 2256x1504
#
#                                       Cpu  Ram              Memory  \
# 2              Intel Core i5 7200U 2.5GHz  8GB           256GB SSD
# 719            Intel Core i7 7500U 2.7GHz  8GB           256GB SSD
# 360              Intel Core i3 6006U 2GHz  4GB           500GB HDD
# 500  Intel Celeron Dual Core N3350 1.1GHz  4GB  64GB Flash Storage
# 670            Intel Core i7 7600U 2.8GHz  8GB           256GB SSD
#
#                               Gpu         OpSys   Weight      Price
# 2           Intel HD Graphics 620         No OS   1.86kg  30636.000
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
sns.histplot(df['Price'],kde=True)
plt.title('Distribution of Prices')
plt.show()

# %%
sns.barplot(df['Company'])
plt.title('Laptop brand analysis')
plt.show()

# %%
df["TypeName"].value_counts().plot(kind="bar")
plt.title('TypeName count')
plt.show()

# %%
sns.boxplot(x="TypeName", y="Price", data=df)
plt.title("Laptop TypeName by Price")
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(df["Inches"],kde='True')
plt.title("Laptop Inches Analysis")
plt.show()

# %%
sns.barplot(x='Inches',y='Price',data=df)
plt.title('Inches by Price Distribution')
plt.xticks(rotation="vertical")
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply (lambda x:1 if 'Touchscreen' in x else 0)

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
plt.title('Touchscreen count')
plt.show()

# %%
sns.violinplot(x='Touchscreen',y='Price',data=df)
plt.title('Touchscreen by Price analysis')
plt.show()

# %%
df["IPS"]=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df['IPS'].value_counts().plot(kind='bar')
plt.title('IPS count')
plt.show()

# %%
sns.violinplot(x='IPS',y='Price',data=df)
plt.title('IPS by Price analysis')
plt.show()

# %%
new=df["ScreenResolution"].str.split('x',n=1,expand=True)

# %%
df["X_res"]=new[0]
df['Y_res']=new[1]

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 366     Dell            Notebook    17.3
# 873   Lenovo            Notebook    13.3
# 576  Toshiba           Ultrabook    14.0
# 608   Lenovo  2 in 1 Convertible    15.6
# 336     Dell           Ultrabook    15.6
#
#                               ScreenResolution                          Cpu  \
# 366                          Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
# 873                IPS Panel Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# 576            Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 608  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 336                IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
#
#      Ram                Memory                    Gpu       OpSys  Weight  \
# 366    8  128GB SSD +  1TB HDD         AMD Radeon 530  Windows 10    2.80
# 873    4             180GB SSD  Intel HD Graphics 620  Windows 10    1.44
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
# finding regular expression

# %%
df.sample()
# Out:
#     Company TypeName  Inches             ScreenResolution  \
# 444      HP   Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 444  Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight     Price  Touchscreen  IPS  \
# 444  Nvidia GeForce GTX 1050  Windows 10     2.2  58554.72            0    1
#
#     X_res Y_res
# 444  1920  1080

# %%
df["X_res"]=df["X_res"].astype("int")
df["Y_res"]=df["Y_res"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')
# formula --->ppi=(x**2+y**2)**0.5/inches

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=["Inches","X_res","Y_res"],inplace=True)

# %%
df
# Out:
#      Company            TypeName                            ScreenResolution  \
# 0      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# 1      Apple           Ultrabook                                    1440x900
# 2         HP            Notebook                           Full HD 1920x1080
# 3      Apple           Ultrabook          IPS Panel Retina Display 2880x1800
# 4      Apple           Ultrabook          IPS Panel Retina Display 2560x1600
# ...      ...                 ...                                         ...
# 1298  Lenovo  2 in 1 Convertible   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  Lenovo  2 in 1 Convertible  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300  Lenovo            Notebook                                    1366x768
# 1301      HP            Notebook                                    1366x768
# 1302    Asus            Notebook                                    1366x768
#
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df["Cpu_Name"]=df["Cpu"].apply(lambda x :" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df["Cpu brand"]=df["Cpu_Name"].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df["Cpu brand"].value_counts().plot(kind="bar")
plt.title('CPU brand analysis')
plt.show()

# %%
sns.boxplot(x=df["Cpu brand"],y=df["Price"])
plt.xticks(rotation="vertical")
plt.title('CPU Brand and price analysis')
plt.show()

# %%
df.sample()
# Out:
#     Company  TypeName   ScreenResolution                         Cpu  Ram  \
# 453  Lenovo  Notebook  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
#
#         Memory                    Gpu       OpSys  Weight    Price  \
# 453  256GB SSD  Intel HD Graphics 620  Windows 10    1.65  71661.6
#
#      Touchscreen  IPS         ppi       Cpu_Name      Cpu brand
# 453            0    0  157.350512  Intel Core i5  Intel Core i5

# %%
# df['Ram']=df['Ram'].value_counts().plot(kind='bar')
# plt.title('RAM count')
# plt.show()

# %%
df.sample(5)
# Out:
#     Company            TypeName       ScreenResolution  \
# 529    Dell            Notebook      Full HD 1920x1080
# 273  Lenovo  2 in 1 Convertible  Touchscreen 2560x1440
# 233    Dell            Notebook      Full HD 1920x1080
# 607  Lenovo            Notebook      Full HD 1920x1080
# 344    Dell           Ultrabook      Full HD 1920x1080
#
#                              Cpu  Ram     Memory                     Gpu  \
# 529  Intel Core i5 7440HQ 2.8GHz    8  256GB SSD   Intel HD Graphics 620
# 273   Intel Core i7 6600U 2.6GHz   16  512GB SSD   Intel HD Graphics 520
# 233   Intel Core i5 7200U 2.5GHz    8  256GB SSD   Intel HD Graphics 620
# 607   Intel Core i5 7200U 2.5GHz    6    1TB HDD   Intel HD Graphics 620
# 344   Intel Core i7 8550U 1.8GHz    8  256GB SSD  Intel UHD Graphics 620
#
#           OpSys  Weight      Price  Touchscreen  IPS         ppi  \
# 529  Windows 10    1.90   73366.56            0    0  141.211998
# ...

# %%
sns.barplot(x=df["Ram"],y=df["Price"])
plt.title('RAM and price analysis')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# normalizing memory column
m = (
    df['Memory']
    .astype(str)
    .str.replace('.0', '', regex=False)
    .str.replace('TB', '000', regex=False)
    .str.replace('GB', '', regex=False)
)
"""regex defines what to find and extract pulls out that value and expand = false means as extract returns a data 
frame setting expand = false means return a data series instead"""

# extracting storage sizes
df['HDD'] = m.str.extract(r'(\d+)\s*HDD', expand=False).fillna(0).astype(int)
df['SSD'] = m.str.extract(r'(\d+)\s*SSD', expand=False).fillna(0).astype(int)
df['Hybrid'] = m.str.extract(r'(\d+)\s*Hybrid', expand=False).fillna(0).astype(int)
df['Flash_Storage'] = m.str.extract(r'(\d+)\s*Flash Storage', expand=False).fillna(0).astype(int)

# %%
df.drop(columns=["Memory"],inplace=True)

# %%
df.drop(columns=["ScreenResolution"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Cpu            1303 non-null   object
#  3   Ram            1303 non-null   int32
#  4   Gpu            1303 non-null   object
#  5   OpSys          1303 non-null   object
#  6   Weight         1303 non-null   float32
#  7   Price          1303 non-null   float64
#  8   Touchscreen    1303 non-null   int64
#  9   IPS            1303 non-null   int64
#  10  ppi            1303 non-null   float64
#  11  Cpu_Name       1303 non-null   object
#  12  Cpu brand      1303 non-null   object
#  13  HDD            1303 non-null   int64
#  14  SSD            1303 non-null   int64
#  15  Hybrid         1303 non-null   int64
#  16  Flash_Storage  1303 non-null   int64
# ...

# %%
df.drop(columns=["Cpu","Cpu_Name"],inplace=True)

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.095672
# SSD              0.676202
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=["Hybrid","Flash_Storage"],inplace=True)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Ram                     Gpu       OpSys  Weight  \
# 561   Lenovo  Notebook    4   Intel HD Graphics 620  Windows 10    2.05
# 644     Acer  Notebook    4   Intel HD Graphics 520  Windows 10    2.40
# 475     Dell  Notebook    8   Intel HD Graphics 520  Windows 10    1.79
# 839     Asus  Notebook    8   Intel HD Graphics 620  Windows 10    2.30
# 1171      HP  Notebook   16  Intel UHD Graphics 620  Windows 10    2.10
#
#          Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD
# 561   33566.40            0    0  141.211998  Intel Core i3    0  128
# 644   23976.00            0    0  100.454670  Intel Core i3  500    0
# 475   39427.20            0    0  111.935204  Intel Core i3    0  128
# 839   31435.20            0    0  141.211998  Intel Core i5  128    0
# 1171  61751.52            0    0  141.211998  Intel Core i7    0  512

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_brand']=df["Gpu"].apply(lambda x:x.split()[0])

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df['Gpu_brand']!='ARM']

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   OpSys        1302 non-null   object
#  4   Weight       1302 non-null   float32
#  5   Price        1302 non-null   float64
#  6   Touchscreen  1302 non-null   int64
#  7   IPS          1302 non-null   int64
#  8   ppi          1302 non-null   float64
#  9   Cpu brand    1302 non-null   object
#  10  HDD          1302 non-null   int64
#  11  SSD          1302 non-null   int64
#  12  Gpu_brand    1302 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 132.2+ KB

# %%
sns.barplot(x=df["Gpu_brand"],y=df["Price"])
plt.title('GPU brand and price analysis')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   OpSys        1302 non-null   object
#  4   Weight       1302 non-null   float32
#  5   Price        1302 non-null   float64
#  6   Touchscreen  1302 non-null   int64
#  7   IPS          1302 non-null   int64
#  8   ppi          1302 non-null   float64
#  9   Cpu brand    1302 non-null   object
#  10  HDD          1302 non-null   int64
#  11  SSD          1302 non-null   int64
#  12  Gpu_brand    1302 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 132.2+ KB

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df["Price"])
plt.xticks(rotation="vertical")
plt.title("Operating system and price analysis")
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os']=df["OpSys"].apply(cat_os)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13696\1355744796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os']=df["OpSys"].apply(cat_os)

# %%
df.sample(6)
# Out:
#      Company   TypeName  Ram       OpSys  Weight        Price  Touchscreen  \
# 587   Lenovo  Ultrabook   12  Windows 10    1.40   89137.4400            0
# 324     Acer   Notebook    8  Windows 10    2.20   35111.5200            0
# 1197    Asus     Gaming   16  Windows 10    4.30  114552.0000            0
# 1034      HP   Notebook    8  Windows 10    1.84   65480.5872            0
# 119     Asus   Notebook    8  Windows 10    1.70   59567.0400            0
# 506     Asus   Notebook    8  Windows 10    2.00   65214.7200            0
#
#       IPS         ppi      Cpu brand   HDD  SSD Gpu_brand       os
# 587     1  157.350512  Intel Core i7     0  256     Intel  Windows
# 324     0  100.454670  AMD Processor     0  256       AMD  Windows
# 1197    1  127.335675  Intel Core i7  1000  512    Nvidia  Windows
# 1034    0  141.211998  Intel Core i7     0  256     Intel  Windows
# 119     0  141.211998  Intel Core i7     0  256    Nvidia  Windows
# ...

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13696\3105339334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
sns.boxplot(x=df['os'],y=df["Price"])
plt.xticks(rotation="vertical")
plt.title("Operating system and price analysis")
plt.show()

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
plt.title('Analysis of weight with price')
plt.show()

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.475368
# HDD           -0.096122
# SSD            0.676066
# Name: Price, dtype: float64

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram  Weight      Price  Touchscreen  IPS  \
# 1202    Dell  2 in 1 Convertible   16     2.0   68464.80            1    0
# 1124    Asus            Notebook    4     2.0   23176.80            0    0
# 1285  Lenovo  2 in 1 Convertible   16     1.3   79866.72            1    1
# 1083      HP           Ultrabook   16     1.3  109170.72            0    1
# 1000    Acer              Gaming    8     2.7   67132.80            0    1
#
#              ppi      Cpu brand   HDD  SSD Gpu_brand       os
# 1202  141.211998  Intel Core i7     0  512     Intel  Windows
# 1124  100.454670  Intel Core i3  1000    0     Intel  Windows
# 1285  276.053530  Intel Core i7     0  512     Intel  Windows
# 1083  331.264236  Intel Core i7     0  512     Intel  Windows
# 1000  141.211998  Intel Core i7  1000  128    Nvidia  Windows

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.histplot(np.log(df['Price']),kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1041, 12)
# (261, 12)
# (1041,)
# (261,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
# %pip install xgboost
from xgboost import XGBRegressor
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Price        1302 non-null   float64
#  5   Touchscreen  1302 non-null   int64
#  6   IPS          1302 non-null   int64
#  7   ppi          1302 non-null   float64
#  8   Cpu brand    1302 non-null   object
#  9   HDD          1302 non-null   int64
#  10  SSD          1302 non-null   int64
#  11  Gpu_brand    1302 non-null   object
#  12  os           1302 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 132.2+ KB

# %%
categorical_cols = ['Company','TypeName','Cpu brand','Gpu_brand','os']

# %% [markdown]
# LinearRegression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8032629320124935
# MAE 0.20336497589268396

# %% [markdown]
# RIDGE REGRESSION:
# (LINEAR+L2 REGULARIZATION)

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8032629320124935
# MAE 0.20336497589268396

# %% [markdown]
# LASSO:

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7985851131429745
# MAE 0.20557279357102606

# %% [markdown]
# KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7985851131429745
# MAE 0.20557279357102606

# %% [markdown]
# DECISION TREE

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8198823624250338
# MAE 0.19454551316287702

# %% [markdown]
# SVR:

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7791317200347797
# MAE 0.20053615380481718

# %% [markdown]
# RANDOM FOREST

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8685547440862008
# MAE 0.16397681423300042

# %% [markdown]
# ADA BOOST

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7856411354552411
# MAE 0.22671779818343624

# %% [markdown]
# GRADIENT BOOST:

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8647109719153143
# MAE 0.16214444659838112

# %% [markdown]
# XGBOOST REGRESSOR

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8636399511829496
# MAE 0.1669341483077864

# %% [markdown]
# VOTING REGRESSOR:

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb)],weights=[5,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8760459608922243
# MAE 0.16001288404190347

# %% [markdown]
# STACKING REGRESSOR:

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),categorical_cols)
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8722877542709646
# MAE 0.16465448160214358

# %% [markdown]
# EXPORTING THE MODEL:

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...
